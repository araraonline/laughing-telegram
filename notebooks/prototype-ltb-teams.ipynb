# %% [markdown]
# # Prototype linking teams from loteca to betexp
#
# In this notebook, we will try linking lotecaa matches into BetExplorer
# matches. I know this has been done before, but we want a clearer approach.
#
# Just a bit of code will be redone. Let's aim to keep most of what can be kept.

# %%
import logging
import sqlite3

# %%
import sys
sys.path.append('..')

# %%
from src.util import load_pickle

# %%
# from src.data.interim.teams import betexplorer
from src.data.interim.teams import betexplorer, loteca

# %% [markdown]
# ## Loading the data
#
# First we will load the teams and calculate some of
# their properties in both end of the thing.
#
# Our wanted result is a list of `Team`s for each source.

# %%
def retrieve_loteca_teams():
    datapath = '../data/process/loteca_matches.pkl'
    teams = loteca.retrieve_teams(datapath)
    return teams

def retrieve_betexp_teams():
    dbpath = '../data/db.sqlite3'
    teams = betexplorer.retrieve_teams(dbpath)
    return teams

# %%
loteca_teams = retrieve_loteca_teams()
betexp_teams = retrieve_betexp_teams()
# Out:
# ERROR:root:Found multiple states for fname 'bragantino'

# %% [markdown]
# ## Bragantino

# %%
[t for t in betexp_teams if t.fname == 'bragantino']
# Out:
# [Team ("Bragantino U20"), Team ("Bragantino")]

# %%
import pandas as pd

conn = sqlite3.connect('../data/db.sqlite3')
df = pd.read_sql_query("SELECT * FROM betexp_matches WHERE league_category == 'brazil'", conn)
conn.close()

# %%
teams = ['Bragantino', 'Bragantino U20']
df[(df.team_h.isin(teams)) |
   (df.team_a.isin(teams))]
# Out:
#              id                                                url  \
# 380    GtN3bsu5  http://www.betexplorer.com/soccer/brazil/serie...
# 392    Gxs5mQQn  http://www.betexplorer.com/soccer/brazil/serie...
# 403    W6pzWOeC  http://www.betexplorer.com/soccer/brazil/serie...
# 416    AsH5wzDR  http://www.betexplorer.com/soccer/brazil/serie...
# 427    YswGDJqG  http://www.betexplorer.com/soccer/brazil/serie...
# 438    GfKU5qUs  http://www.betexplorer.com/soccer/brazil/serie...
# 443    YwEvAvbf  http://www.betexplorer.com/soccer/brazil/serie...
# 458    6ZGRG2jE  http://www.betexplorer.com/soccer/brazil/serie...
# 463    619F03yL  http://www.betexplorer.com/soccer/brazil/serie...
# 479    UVjgz3p2  http://www.betexplorer.com/soccer/brazil/serie...
# 484    tjfcwhWT  http://www.betexplorer.com/soccer/brazil/serie...
# 496    vu7KMY1U  http://www.betexplorer.com/soccer/brazil/serie...
# 509    Krn18eIO  http://www.betexplorer.com/soccer/brazil/serie...
# 513    WCAJBJ3g  http://www.betexplorer.com/soccer/brazil/serie...
# 522    hnV547De  http://www.betexplorer.com/soccer/brazil/serie...
# 538    Kh1eAsuT  http://www.betexplorer.com/soccer/brazil/serie...
# 548    IZJEjrJp  http://www.betexplorer.com/soccer/brazil/serie...
# 550    E1R6uoRN  http://www.betexplorer.com/soccer/brazil/serie...
# 569    jJ0GvGjf  http://www.betexplorer.com/soccer/brazil/serie...
# 570    vBVGnvqE  http://www.betexplorer.com/soccer/brazil/serie...
# 583    YDCJqLEE  http://www.betexplorer.com/soccer/brazil/serie...
# 593    hOzrCMpS  http://www.betexplorer.com/soccer/brazil/serie...
# 608    tt9RDrGF  http://www.betexplorer.com/soccer/brazil/serie...
# 613    Ykh1dhe5  http://www.betexplorer.com/soccer/brazil/serie...
# 620    rDVOdEQh  http://www.betexplorer.com/soccer/brazil/serie...
# 638    4lP8sedg  http://www.betexplorer.com/soccer/brazil/serie...
# 643    tACtwUo1  http://www.betexplorer.com/soccer/brazil/serie...
# 651    f5CZdvI9  http://www.betexplorer.com/soccer/brazil/serie...
# 663    ADnFZrWr  http://www.betexplorer.com/soccer/brazil/serie...
# 679    WjNdOYrC  http://www.betexplorer.com/soccer/brazil/serie...
# ...         ...                                                ...
# 19239  xOM2BK1A  http://www.betexplorer.com/soccer/brazil/campe...
# 19244  8rVoF22o  http://www.betexplorer.com/soccer/brazil/campe...
# 19251  ze0Xeu2N  http://www.betexplorer.com/soccer/brazil/campe...
# 19254  YDY0cXLU  http://www.betexplorer.com/soccer/brazil/campe...
# 19261  86yk0ZyC  http://www.betexplorer.com/soccer/brazil/campe...
# 19267  WMwIctGD  http://www.betexplorer.com/soccer/brazil/campe...
# 19269  bXo50rWf  http://www.betexplorer.com/soccer/brazil/campe...
# 19273  pQ5U6pgR  http://www.betexplorer.com/soccer/brazil/campe...
# 19280  QktWm5nk  http://www.betexplorer.com/soccer/brazil/campe...
# 19361  rgi1alPG  http://www.betexplorer.com/soccer/brazil/campe...
# 19366  Eapo3WPi  http://www.betexplorer.com/soccer/brazil/campe...
# 19370  SUQ4y5dF  http://www.betexplorer.com/soccer/brazil/campe...
# 19380  OzqwN5sM  http://www.betexplorer.com/soccer/brazil/campe...
# 19386  fsCmClT3  http://www.betexplorer.com/soccer/brazil/campe...
# 19395  zwqRfmbT  http://www.betexplorer.com/soccer/brazil/campe...
# 19408  ph6Fxlxo  http://www.betexplorer.com/soccer/brazil/campe...
# 19414  0niGtcwJ  http://www.betexplorer.com/soccer/brazil/campe...
# 19424  0SOUUav7  http://www.betexplorer.com/soccer/brazil/campe...
# 19430  nFaowOWQ  http://www.betexplorer.com/soccer/brazil/campe...
# 19436  vyH4QpmL  http://www.betexplorer.com/soccer/brazil/campe...
# 19442  jFzA43Q1  http://www.betexplorer.com/soccer/brazil/campe...
# 19449  rT9T9wop  http://www.betexplorer.com/soccer/brazil/campe...
# 19457  Kn0vWT1n  http://www.betexplorer.com/soccer/brazil/campe...
# 19854  rLc46zoP  http://www.betexplorer.com/soccer/brazil/copa-...
# 19863  GpvNgc1J  http://www.betexplorer.com/soccer/brazil/copa-...
# 19871  A5jbwJ1P  http://www.betexplorer.com/soccer/brazil/copa-...
# 19924  pAXY7ti3  http://www.betexplorer.com/soccer/brazil/copa-...
# 20161  vq9qtAYB  http://www.betexplorer.com/soccer/brazil/copa-...
# 20233  2Lrrewao  http://www.betexplorer.com/soccer/brazil/copa-...
# 20279  pM9usjJ5  http://www.betexplorer.com/soccer/brazil/copa-...
#
#       league_category                 league_name league_year  \
# 380            brazil                     Série B        2009
# 392            brazil                     Série B        2009
# 403            brazil                     Série B        2009
# 416            brazil                     Série B        2009
# 427            brazil                     Série B        2009
# 438            brazil                     Série B        2009
# 443            brazil                     Série B        2009
# 458            brazil                     Série B        2009
# 463            brazil                     Série B        2009
# 479            brazil                     Série B        2009
# 484            brazil                     Série B        2009
# 496            brazil                     Série B        2009
# 509            brazil                     Série B        2009
# 513            brazil                     Série B        2009
# 522            brazil                     Série B        2009
# 538            brazil                     Série B        2009
# 548            brazil                     Série B        2009
# 550            brazil                     Série B        2009
# 569            brazil                     Série B        2009
# 570            brazil                     Série B        2009
# 583            brazil                     Série B        2009
# 593            brazil                     Série B        2009
# 608            brazil                     Série B        2009
# 613            brazil                     Série B        2009
# 620            brazil                     Série B        2009
# 638            brazil                     Série B        2009
# 643            brazil                     Série B        2009
# 651            brazil                     Série B        2009
# 663            brazil                     Série B        2009
# 679            brazil                     Série B        2009
# ...               ...                         ...         ...
# 19239          brazil         Campeonato Paraense        2018
# 19244          brazil         Campeonato Paraense        2018
# 19251          brazil         Campeonato Paraense        2018
# 19254          brazil         Campeonato Paraense        2018
# 19261          brazil         Campeonato Paraense        2018
# 19267          brazil         Campeonato Paraense        2018
# 19269          brazil         Campeonato Paraense        2018
# 19273          brazil         Campeonato Paraense        2018
# 19280          brazil         Campeonato Paraense        2018
# 19361          brazil         Campeonato Paulista        2018
# 19366          brazil         Campeonato Paulista        2018
# 19370          brazil         Campeonato Paulista        2018
# 19380          brazil         Campeonato Paulista        2018
# 19386          brazil         Campeonato Paulista        2018
# 19395          brazil         Campeonato Paulista        2018
# 19408          brazil         Campeonato Paulista        2018
# 19414          brazil         Campeonato Paulista        2018
# 19424          brazil         Campeonato Paulista        2018
# 19430          brazil         Campeonato Paulista        2018
# 19436          brazil         Campeonato Paulista        2018
# 19442          brazil         Campeonato Paulista        2018
# 19449          brazil         Campeonato Paulista        2018
# 19457          brazil         Campeonato Paulista        2018
# 19854          brazil              Copa do Brasil        2018
# 19863          brazil              Copa do Brasil        2018
# 19871          brazil              Copa do Brasil        2018
# 19924          brazil              Copa do Brasil        2018
# 20161          brazil  Copa Sao Paulo de juniores        2018
# 20233          brazil  Copa Sao Paulo de juniores        2018
# 20279          brazil  Copa Sao Paulo de juniores        2018
#
#                 team_h           team_a        date score scoremod
# 380                ABC       Bragantino  28.11.2009   0:1
# 392         Bragantino      Brasiliense  21.11.2009   1:2
# 403        Figueirense       Bragantino  14.11.2009   2:1
# 416         Bragantino           Parana  10.11.2009   2:2
# 427              Ceara       Bragantino  04.11.2009   2:0
# 438         Bragantino       America RN  28.10.2009   2:1
# 443         Bragantino        Fortaleza  24.10.2009   4:1
# 458        Ponte Preta       Bragantino  20.10.2009   2:1
# 463         Bragantino            Bahia  17.10.2009   3:0
# 479       Vila Nova FC       Bragantino  07.10.2009   1:2
# 484         Bragantino            Vasco  03.10.2009   0:0
# 496         Portuguesa       Bragantino  30.09.2009   2:0
# 509         Bragantino        Juventude  23.09.2009   3:2
# 513         Campinense       Bragantino  19.09.2009   2:0
# 522              Betim       Bragantino  16.09.2009   2:0
# 538         Bragantino          Guarani  09.09.2009   0:1
# 548    Duque de Caxias       Bragantino  02.09.2009   0:1
# 550         Bragantino      Atletico GO  30.08.2009   2:2
# 569        Sao Caetano       Bragantino  26.08.2009   3:0
# 570         Bragantino              ABC  23.08.2009   3:0
# 583        Brasiliense       Bragantino  15.08.2009   2:1
# 593         Bragantino      Figueirense  12.08.2009   1:0
# 608             Parana       Bragantino  05.08.2009   4:1
# 613         Bragantino            Ceara  01.08.2009   1:1
# 620         America RN       Bragantino  29.07.2009   1:4
# 638          Fortaleza       Bragantino  22.07.2009   1:2
# 643         Bragantino      Ponte Preta  18.07.2009   1:1
# 651              Bahia       Bragantino  15.07.2009   1:1
# 663         Bragantino     Vila Nova FC  11.07.2009   2:1
# 679              Vasco       Bragantino  01.07.2009   0:0
# ...                ...              ...         ...   ...      ...
# 19239        Castanhal       Bragantino  11.03.2018   0:1
# 19244       Bragantino      Paragominas  04.03.2018   2:2
# 19251  SAO Raimundo PA       Bragantino  25.02.2018   1:0
# 19254       Bragantino             Remo  18.02.2018   3:2
# 19261      Parauapebas       Bragantino  04.02.2018   2:4
# 19267       Bragantino        Castanhal  27.01.2018   0:1
# 19269      Paragominas       Bragantino  25.01.2018   2:3
# 19273       Bragantino  SAO Raimundo PA  21.01.2018   2:1
# 19280             Remo       Bragantino  14.01.2018   3:0
# 19361      Corinthians       Bragantino  23.03.2018   2:0
# 19366       Bragantino      Corinthians  18.03.2018   3:2
# 19370       Bragantino      Sao Caetano  11.03.2018   1:1
# 19380      Ferroviaria       Bragantino  08.03.2018   0:0
# 19386      Ponte Preta       Bragantino  06.03.2018   0:1
# 19395       Bragantino    Novorizontino  25.02.2018   2:1
# 19408      Santo Andre       Bragantino  17.02.2018   1:1
# 19414       Bragantino         Mirassol  14.02.2018   0:0
# 19424        Sao Paulo       Bragantino  08.02.2018   1:0
# 19430  Red Bull Brasil       Bragantino  03.02.2018   1:1
# 19436       Bragantino        Palmeiras  28.01.2018   0:2
# 19442       Bragantino        Sao Bento  25.01.2018   0:1
# 19449           Santos       Bragantino  22.01.2018   0:1
# 19457       Bragantino      Botafogo SP  18.01.2018   2:0
# 19854          Vitoria       Bragantino  15.03.2018   3:0
# 19863       Bragantino          Vitoria  28.02.2018   1:0
# 19871       Bragantino         AE Altos  22.02.2018   1:0
# 19924      Nova Iguacu       Bragantino  31.01.2018   1:1
# 20161   Bragantino U20     Trindade U20  08.01.2018   0:4
# 20233   Uniao Mogi U20   Bragantino U20  05.01.2018   1:2
# 20279       Gremio U20   Bragantino U20  03.01.2018   3:0
#
# [510 rows x 10 columns]

# %% [markdown]
# There are two `Bragantino`s:
#
# - One from São Paulo ([1])
# - And one from Pará ([2])
#
# Both of them are called `Bragantino` in the BetExplorer database. We hope
# this error is not common, as it could bring some problems.
#
# [1]: https://pt.wikipedia.org/wiki/Clube_Atl%C3%A9tico_Bragantino
# [2]: https://pt.wikipedia.org/wiki/Bragantino_Clube_do_Par%C3%A1

# %% [markdown]
# ### Problematic cases
#
# We are working under the assumption that each `fname` corresponds to one
# team and one team only.
#
# As seen above, however, this assumption is not true.
#
# In our state matching, this may assign the wrong state to a team. It may happen
# under the following circumstances:
#
# - Two teams from different states share the same `fname`.
# - One of the teams plays in intra-state matches.
# - The other one only plays in inter-state matches.
#
# The state for the teams will be retrieved from the intra-state matches. As one
# of the teams only play in inter-state matches, the state for this team will not
# be retrieved.
#
# There won't be any conflict, and both teams will be assigned to the same state.
#
# #### Rarity
#
# This setup, however, is pretty hard to happen. When a team plays on the inter-state
# matches, we also expect it to play on the intra-state matches, as it is presumably
# big.
#
# The needed setup forbids this.

# %% [markdown]
# ## Everything

# %%
loteca_teams = retrieve_loteca_teams()
betexp_teams = retrieve_betexp_teams()
# Out:
# ERROR:root:Found multiple states for fname 'bragantino'

# %%
# GENERATE COUNTRIES DICT

# load countries
countries = load_pickle('../data/interim/countries.pkl')

# standardize country names
def standardize_country(name):
    from unidecode import unidecode
    return unidecode(name).lower()
_sc = standardize_country
countries = {_sc(k): _sc(v) for k, v in countries.items()}

# manual updates
updates = {
    'bosnia herzegovina': 'bosnia & herzegovina',
    'camaroes': 'cameroon',
    'costa do marfim': 'ivory coast',
    'escocia': 'scotland',
    'estados unidos': 'usa',
    'inglaterra': 'england',
    'irlanda do norte': 'northern ireland',
    'pais de gales': 'wales',
    'rep.tcheca': 'czech republic',
    'republica tcheca': 'czech republic',
    'servia e montenegro': 'serbia and montenegro',
    'taiti': 'tahiti',
}
countries.update(updates)

# %%
import logging
import re

from src.util import re_strip

LOTECA_MAX_SIZE = max(len(str(t)) for t in loteca_teams)

    
def is_same_team(loteca_team, betexp_team):
    lt = loteca_team
    be = betexp_team
    
    # strict restrictions
    if lt.women_flag != be.women_flag:
        return False
    if lt.under != be.under:
        return False
    if (lt.state and be.state and
          lt.state != be.state):
        return False
    
    # split case
    if not lt.state and not lt.country:
        # country team
        return countries[lt.fname] == be.fname
    elif lt.country:
        # teams outside of brazil
        return (be.state is None and
                  be.fname == lt.fname)
    else:
        # teams from brazil
        return (lt.state == be.state and
                  lt.fname_without_state == be.fname_without_state)        

ltb_dict = {}
for loteca_team in loteca_teams:
    # get matching BetExplorer strings
    matching_teams = [t for t in betexp_teams if is_same_team(loteca_team, t)]
    betexp_strings = [betexplorer.generate_string(t) for t in matching_teams]
    betexp_strings = set(betexp_strings)
    
    # log founds
    msg = "{loteca_string!s:>{loteca_max_size}} -> {found}"
    msg = msg.format(loteca_string=loteca_team.string,
                     loteca_max_size=LOTECA_MAX_SIZE,
                     found=betexp_strings if betexp_strings else "{}")
    log_level = logging.ERROR if len(betexp_strings) > 1 else logging.INFO
    logging.log(log_level, msg)
        
    # save
    ltb_dict[loteca_team.string] = betexp_strings
