# %% [markdown]
# Some of the Loteca matches have wrong Timestamps with them.
#
# Let's examine this and try to come up with a way for retrieving the dates without using the wrong timestamps!

# %%
import pickle

import numpy as np
import pandas as pd

rounds = pickle.load(open('../data/raw/loteca_site.pkl', mode='rb'))
matches = pd.read_pickle('../data/pre/lotecas_matches.pkl')  # already preprocessed

# %%
rounds[0]
# Out:
# {'colunaDois': True,
#  'colunaMeio': False,
#  'colunaUm': False,
#  'concurso': 1,
#  'concursoAnterior': None,
#  'concursosProgramacao': None,
#  'de_observacao': 'Estimativa prêmio para o próximo concurso: 14 pontos: 130 MIL.',
#  'dtApuracao': 1014001200000,
#  'dtApuracaoStr': '18/02/2002',
#  'dt_jogo': 1013914800000,
#  'dt_proximo_concurso': None,
#  'dt_proximo_concursoStr': None,
#  'error': False,
#  'forward': None,
#  'ganhadoresPorUf': [{'coLoteria': '9',
#    'concursoAnterior': None,
#    'forward': None,
#    'icCanalEletronico': None,
#    'mensagens': [],
#    'noCidade': None,
#    'nuConcurso': '1',
#    'proximoConcurso': None,
#    'qtGanhadores': 1,
#    'sgUf': 'BA',
#    'total': None},
#   {'coLoteria': '9',
#    'concursoAnterior': None,
#    'forward': None,
#    'icCanalEletronico': None,
#    'mensagens': [],
#    'noCidade': None,
#    'nuConcurso': '1',
#    'proximoConcurso': None,
#    'qtGanhadores': 1,
#    'sgUf': 'SP',
#    'total': None}],
#  'icJogo': '1',
#  'ic_sorteio': '0',
#  'jogos': [{'colunaDois': True,
#    'colunaMeio': False,
#    'colunaUm': False,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '1',
#    'noTime1': 'FLAMENGO/RJ',
#    'noTime2': 'S. PAULO/SP',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '4',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '2',
#    'noTime1': 'VASCO/RJ',
#    'noTime2': 'AMERICANO/RJ',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '3',
#    'qt_gol_time2': '0',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '3',
#    'noTime1': 'SANTOS/SP',
#    'noTime2': 'SÃO  CAETANO/SP',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '1',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': True,
#    'colunaMeio': False,
#    'colunaUm': False,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '4',
#    'noTime1': 'P.  DESPORTOS/SP',
#    'noTime2': 'CORINTHIANS/SP',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '1',
#    'qt_gol_time2': '4',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Sábado',
#    'dtApuracao': None,
#    'dt_jogo': 1013824800000,
#    'icJogo': '5',
#    'noTime1': 'CRUZEIRO/MG',
#    'noTime2': 'AMÉRICA/MG',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '7',
#    'qt_gol_time2': '0',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': True,
#    'colunaMeio': False,
#    'colunaUm': False,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '6',
#    'noTime1': 'JUVENTUDE/RS',
#    'noTime2': 'ATLÉTICO/MG',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '1',
#    'qt_gol_time2': '2',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': True,
#    'colunaUm': False,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '7',
#    'noTime1': 'CORITIBA/PR',
#    'noTime2': 'FIGUEIRENSE/SC',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '2',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Sábado',
#    'dtApuracao': None,
#    'dt_jogo': 1013824800000,
#    'icJogo': '8',
#    'noTime1': 'CRICIÚMA/SC',
#    'noTime2': 'ATLÉTICO/PR',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '1',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': True,
#    'colunaUm': False,
#    'concurso': None,
#    'diaDaSemana': 'Sábado',
#    'dtApuracao': None,
#    'dt_jogo': 1013824800000,
#    'icJogo': '9',
#    'noTime1': 'GRÊMIO/RS',
#    'noTime2': 'JOINVILLE/SC',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '1',
#    'qt_gol_time2': '1',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '10',
#    'noTime1': 'BAHIA/BA',
#    'noTime2': 'SANTA CRUZ/PE',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '0',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '11',
#    'noTime1': 'NÁUTICO/PE',
#    'noTime2': 'VITÓRIA/BA',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '1',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': True,
#    'colunaMeio': False,
#    'colunaUm': False,
#    'concurso': None,
#    'diaDaSemana': 'Sábado',
#    'dtApuracao': None,
#    'dt_jogo': 1013824800000,
#    'icJogo': '12',
#    'noTime1': 'BANGU/RJ',
#    'noTime2': 'PALMEIRAS/SP',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '1',
#    'qt_gol_time2': '3',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Sábado',
#    'dtApuracao': None,
#    'dt_jogo': 1013824800000,
#    'icJogo': '13',
#    'noTime1': 'ETTI  JUNDIAÍ/SP',
#    'noTime2': 'FLUMINENSE/RJ',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '3',
#    'qt_gol_time2': '0',
#    'vrAcumuladoFaixa1': None},
#   {'colunaDois': False,
#    'colunaMeio': False,
#    'colunaUm': True,
#    'concurso': None,
#    'diaDaSemana': 'Domingo',
#    'dtApuracao': None,
#    'dt_jogo': 1013914800000,
#    'icJogo': '14',
#    'noTime1': 'PONTE PRETA/SP',
#    'noTime2': 'BOTAFOGO/RJ',
#    'qtGanhadorFaixa1': None,
#    'qt_gol_time1': '2',
#    'qt_gol_time2': '0',
#    'vrAcumuladoFaixa1': None}],
#  'legendaFinal': None,
#  'localSorteio': None,
#  'mensagens': [],
#  'noTime1': 'FLAMENGO/RJ',
#  'noTime2': 'S. PAULO/SP',
#  'nuConcursoAcumulado': None,
#  'proximoConcurso': '2',
#  'qtGanhadorFaixa1': '2',
#  'qtGanhadorFaixa2': '44',
#  'qtGanhadorFaixa3': '1028',
#  'qt_gol_time1': '2',
#  'qt_gol_time2': '4',
#  'rateioProcessamento': False,
#  'sorteioAcumulado': False,
#  'sorteioAcumuladoCinco': True,
#  'ultimoConcurso': False,
#  'vrAcumuladoFaixa1': 0.0,
#  'vrArrecadado': None,
#  'vrConcursoAcumulado': None,
#  'vrEstimativa': None,
#  'vrRateioFaixa1': 55985.99,
#  'vrRateioFaixa2': 2544.81,
#  'vrRateioFaixa3': 144.68}

# %%
matches.head()
# Out:
#    roundno  gameno       date             teamH  goalsH            teamA  \
# 0        1       1 2002-02-17       FLAMENGO/RJ       2      S. PAULO/SP
# 1        1       2 2002-02-17          VASCO/RJ       3     AMERICANO/RJ
# 2        1       3 2002-02-17         SANTOS/SP       2  SÃO  CAETANO/SP
# 3        1       4 2002-02-17  P.  DESPORTOS/SP       1   CORINTHIANS/SP
# 4        1       5 2002-02-16       CRUZEIRO/MG       7       AMÉRICA/MG
#
#    goalsA  happened
# 0       4      True
# 1       0      True
# 2       1      True
# 3       4      True
# 4       0      True

# %%
# we can use both the timestamp or string

for round in rounds:
    roundno = round['concurso']    
    rounddate_ts = round['dtApuracao']
    rounddate_str = round['dtApuracaoStr']
    
    date1 = pd.to_datetime(rounddate_ts, unit='ms').normalize()
    date2 = pd.to_datetime(rounddate_str, dayfirst=True)
    
    assert date1 == date2

# %%
WEEKDAYS = {
    'Segunda-feira': 0,
    'Terça-feira': 1,
    'Quarta-feira': 2,
    'Quinta-feira': 3,
    'Sexta-feira': 4,
    'Sábado': 5,
    'Domingo': 6,
    '': np.nan  # Sorteio
}

def find_previous_weekday(date, weekday):
    if date.dayofweek > weekday:
        daysbefore = date.dayofweek - weekday
    else:
        daysbefore = date.dayofweek + (7 - weekday)
        
    return date - pd.Timedelta(days=daysbefore)



matches = []
days = set()
for round in rounds:
    roundno = round['concurso']
    round_date = pd.to_datetime(round['dtApuracaoStr'], dayfirst=True)  # easier
    
    for match in round['jogos']:
        match_weekday = WEEKDAYS[match['diaDaSemana']]
        match_happened = ~np.isnan(match_weekday)
        
        if match_happened:            
            matchno = match['icJogo']
            match_date = find_previous_weekday(round_date, match_weekday)
        
            date1 = match_date
            date2 = pd.to_datetime(match['dt_jogo'], unit='ms').normalize()
            
            if date1 != date2:
                if abs(date1 - date2).days != 7:
                    print(roundno, matchno)
                    print(date1, date2)
                    print()
# Out:
# 548 1
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 2
# 2013-03-02 00:00:00 2013-02-02 00:00:00
#
# 548 3
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 4
# 2013-03-02 00:00:00 2013-02-02 00:00:00
#
# 548 5
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 7
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 8
# 2013-03-02 00:00:00 2013-02-02 00:00:00
#
# 548 9
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 10
# 2013-03-02 00:00:00 2013-02-02 00:00:00
#
# 548 11
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 12
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 13
# 2013-03-03 00:00:00 2013-02-03 00:00:00
#
# 548 14
# 2013-03-03 00:00:00 2013-02-03 00:00:00

# %% [markdown]
# We found that:
# - some matches happen on the day of the draw (example: round 18 matchno 3)
# - some matches happen one week before the draw (example: round 563 matchno 4)
#
# I will just believe those matches that are one week later or one week before. This leaves us with round number 548. All matches happened in march, but the timestamps tell us they happened in february. Let's just fix this manually.
#
# And we're done!
